# %%
import json
fn = "./bird-game-client/src/plantdata.json"

# %%
with open(fn, "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
birdcates = ["maffulg", "sporfugl","sjofugl", "vatnafugl", "vadfugl", "landfugl"]
treecates = [""]
s = ""
for i in range(len(cates)):
    s += cates[i] + f"({i}) "

# %%
print(s)
# Out:
# maffulg(0) sporfugl(1) sjofugl(2) vatnafugl(3) vadfugl(4) landfugl(5)

# %%
for item in data:
    if "category" not in item:
        print(item["name"])
        cate = int(input())
        item["category"] = cate
# Out:
# Lómur
# 3
# Himbrimi
# 3
# Húsönd
# 3
# Dílaskarfur
# 2
# Fýll
# 2
# Súla
# 2
# Álka
# 2
# Lundi
# 2
# Teista
# 2
# Stuttnefja
# 2
# Langvía
# 2
# Fálki
# 5
# Smyrill
# 5
# Haförn
# 5
# Brandugla
# 5
# Rjúpa
# 5
# Stelkur
# 1
# Flórgoði
# 1
# Gargönd
# 3
# Rauðhöfðaönd
# 3
# Helsingi
# 3
# Toppskarfur
# 2
# Hrafnsönd
# 3
# Straumönd
# 3
# Svartþröstur
# 1
# Urtönd
# 3
# Skeiðönd
# 3
# Hvítmáfur
# 0
# Þórshani
# 4
# Bjartmáfur
# 0
# Grafönd
# 3
# Bjargdúfa
# 5
# Blesgæs
# 3
# Brandönd
# 3
# Gulönd
# 3
# Gráspör
# 1
# Sjósvala
# 2
# Gráþröstur
# 1
# Skrofa
# 2
# Stormmáfur
# 0
# Stormsvala
# 2
# Tildra
# 4
# Haftyrðill
# 2
# Glókollur
# 1
# Krossnefur
# 1

# %%
data
# Out:
# [{'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Tjaldur34.jpg',
#   'name': 'Tjaldur',
#   'soundUrl': 'https://fuglavefur.is/audio/tjaldur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/tjaldur.jpg',
#   'category': 4},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Sandloa17.jpg',
#   'name': 'Sandlóa',
#   'soundUrl': 'https://fuglavefur.is/audio/sandloa.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/sandloa.jpg',
#   'category': 4},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Skogarth46.jpg',
#   'name': 'Skógarþröstur',
#   'soundUrl': 'https://fuglavefur.is/audio/skogarthrostur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/skogarthrostur.jpg',
#   'category': 1},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Louthraell22.jpg',
#   'name': 'Lóuþræll',
#   'soundUrl': 'https://fuglavefur.is/audio/louthraell.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/louthraell.jpg',
#   'category': 4},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Sanderla23.jpg',
#   'name': 'Sanderla',
#   'soundUrl': 'https://fuglavefur.is/audio/sanderla.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/sanderla.jpg',
#   'category': 4},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Raudbrystingur31.jpg',
#   'name': 'Rauðbrystingur',
#   'soundUrl': 'https://fuglavefur.is/audio/raudbrystingur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/raudbrystingur.jpg',
#   'category': 4},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Hrossi42.jpg',
#   'name': 'Hrossagaukur',
#   'soundUrl': 'https://fuglavefur.is/audio/hrossagaukur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/hrossagaukur.jpg',
#   'category': 4},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Heidlo40.jpg',
#   'name': 'Heiðlóa',
#   'soundUrl': 'https://fuglavefur.is/audio/heidloa.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/heidloa.jpg',
#   'category': 4},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Sendlingur10.jpg',
#   'name': 'Sendlingur',
#   'soundUrl': 'https://fuglavefur.is/audio/sendlingur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/sendlingur.jpg',
#   'category': 4},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Spoi31.jpg',
#   'name': 'Spói',
#   'soundUrl': 'https://fuglavefur.is/audio/spoi.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/spoi.jpg',
#   'category': 4},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Jadrakan34.jpg',
#   'name': 'Jaðrakan',
#   'soundUrl': 'https://fuglavefur.is/audio/jadrakan.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/jadrakan.jpg',
#   'category': 4},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Odinshani09.jpg',
#   'name': 'Óðinshani',
#   'soundUrl': 'https://fuglavefur.is/audio/odinshani.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/odinshani.jpg',
#   'category': 4},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Hettumafur39.jpg',
#   'name': 'Hettumáfur',
#   'soundUrl': 'https://fuglavefur.is/audio/hettumavur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/hettumavur.jpg',
#   'category': 0},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Kria31.jpg',
#   'name': 'Kría',
#   'soundUrl': 'https://fuglavefur.is/audio/kria.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/kria.jpg',
#   'category': 0},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Silfurmafur22.jpg',
#   'name': 'Silfurmáfur',
#   'soundUrl': 'https://fuglavefur.is/audio/silfurmafur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/silfurmavur.jpg',
#   'category': 0},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Rita28.jpg',
#   'name': 'Rita',
#   'soundUrl': 'https://fuglavefur.is/audio/rita.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/rita.jpg',
#   'category': 0},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Svartbakur21.jpg',
#   'name': 'Svartbakur',
#   'soundUrl': 'https://fuglavefur.is/audio/svartbakur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/svartbakur.jpg',
#   'category': 0},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Silamafur23.jpg',
#   'name': 'Sílamáfur',
#   'soundUrl': 'https://fuglavefur.is/audio/silamavur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/silamavur.jpg',
#   'category': 0},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Skumur14.jpg',
#   'name': 'Skúmur',
#   'soundUrl': 'https://fuglavefur.is/audio/skumur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/skumur.jpg',
#   'category': 0},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Kjoi21.jpg',
#   'name': 'Kjói',
#   'soundUrl': 'https://fuglavefur.is/audio/kjoi.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/kjoi.jpg',
#   'category': 0},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Thufutittl14.jpg',
#   'name': 'Þúfutittlingur',
#   'soundUrl': 'https://fuglavefur.is/audio/thufutittlingur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/thufutittlingur.jpg',
#   'category': 1},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Steindepill12.jpg',
#   'name': 'Steindepill',
#   'soundUrl': 'https://fuglavefur.is/audio/steindepill.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/steindepill.jpg',
#   'category': 1},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Stari51.jpg',
#   'name': 'Stari',
#   'soundUrl': 'https://fuglavefur.is/audio/stari.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/stari.jpg',
#   'category': 1},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Snjotittlingur43.jpg',
#   'name': 'Snjótittlingur',
#   'soundUrl': 'https://fuglavefur.is/audio/snjotittlingur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/snjotittlingur.jpg',
#   'category': 1},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Mariuerla16.jpg',
#   'name': 'Maríuerla',
#   'soundUrl': 'https://fuglavefur.is/audio/mariuerla.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/mariuerla.jpg',
#   'category': 1},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Musarrindill17.jpg',
#   'name': 'Músarrindill',
#   'soundUrl': 'https://fuglavefur.is/audio/musarrindill.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/musarrindill.jpg',
#   'category': 1},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Hrafn65.jpg',
#   'name': 'Hrafn',
#   'soundUrl': 'https://fuglavefur.is/audio/hrafn.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/hrafn.jpg',
#   'category': 1},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Audnutittlingur06e.jpg',
#   'name': 'Auðnutittlingur',
#   'soundUrl': 'https://fuglavefur.is/audio/audnutittlingur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/audnutittlingur.jpg',
#   'category': 1},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Alft53.jpg',
#   'name': 'Álft',
#   'soundUrl': 'https://fuglavefur.is/audio/alft.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/alft.jpg',
#   'category': 1},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Gragaes25.jpg',
#   'name': 'Grágæs',
#   'soundUrl': 'https://fuglavefur.is/audio/gragaes.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/gragaes.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Margaes38.jpg',
#   'name': 'Margæs',
#   'soundUrl': 'https://fuglavefur.is/audio/margaes.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/margaes.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Stokkond35.jpg',
#   'name': 'Stokkönd',
#   'soundUrl': 'https://fuglavefur.is/audio/stokkond.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/stokkond.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Skufond19.jpg',
#   'name': 'Skúfönd',
#   'soundUrl': 'https://fuglavefur.is/audio/skufond.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/skufond.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Duggond14.jpg',
#   'name': 'Duggönd',
#   'soundUrl': 'https://fuglavefur.is/audio/duggond.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/duggond.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Havella32.jpg',
#   'name': 'Hávella',
#   'soundUrl': 'https://fuglavefur.is/audio/havella.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/havella.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Toppond38.jpg',
#   'name': 'Toppönd',
#   'soundUrl': 'https://fuglavefur.is/audio/toppond.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/toppond.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Aedur59.jpg',
#   'name': 'Æðarfugl',
#   'soundUrl': 'https://fuglavefur.is/audio/aedarfugl.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/aedarfugl.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Heidagaes17.jpg',
#   'name': 'Heiðagæs',
#   'soundUrl': 'https://fuglavefur.is/audio/heidagaes.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/heidagaes.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Lomur23.jpg',
#   'name': 'Lómur',
#   'soundUrl': 'https://fuglavefur.is/audio/lomur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/lomur.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Himbrimi22.jpg',
#   'name': 'Himbrimi',
#   'soundUrl': 'https://fuglavefur.is/audio/himbrimi.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/himbrimi.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Husond31.jpg',
#   'name': 'Húsönd',
#   'soundUrl': 'https://fuglavefur.is/audio/husond.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/husond.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Dilaskarfur25.jpg',
#   'name': 'Dílaskarfur',
#   'soundUrl': 'https://fuglavefur.is/audio/dilaskarfur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/dilaskarfur.jpg',
#   'category': 2},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Fyll31.jpg',
#   'name': 'Fýll',
#   'soundUrl': 'https://fuglavefur.is/audio/fyll.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/fyll.jpg',
#   'category': 2},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Sula55.jpg',
#   'name': 'Súla',
#   'soundUrl': 'https://fuglavefur.is/audio/sula.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/sula.jpg',
#   'category': 2},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Alka14.jpg',
#   'name': 'Álka',
#   'soundUrl': 'https://fuglavefur.is/audio/alka.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/alka.jpg',
#   'category': 2},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Lundi344.jpg',
#   'name': 'Lundi',
#   'soundUrl': 'https://fuglavefur.is/audio/lundi.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/lundi.jpg',
#   'category': 2},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Teista10.jpg',
#   'name': 'Teista',
#   'soundUrl': 'https://fuglavefur.is/audio/teista.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/teista.jpg',
#   'category': 2},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Stuttnefja18.jpg',
#   'name': 'Stuttnefja',
#   'soundUrl': 'https://fuglavefur.is/audio/stuttnefja.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/stuttnefja.jpg',
#   'category': 2},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Langvia10.jpg',
#   'name': 'Langvía',
#   'soundUrl': 'https://fuglavefur.is/audio/langvia.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/langvia.jpg',
#   'category': 2},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Falki62.jpg',
#   'name': 'Fálki',
#   'soundUrl': 'https://fuglavefur.is/audio/falki.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/falki.jpg',
#   'category': 5},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Smyrill37.jpg',
#   'name': 'Smyrill',
#   'soundUrl': 'https://fuglavefur.is/audio/smyrill.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/smyrill.jpg',
#   'category': 5},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Orn44.jpg',
#   'name': 'Haförn',
#   'soundUrl': 'https://fuglavefur.is/audio/haforn.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/haforn.jpg',
#   'category': 5},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Brandugla24.jpg',
#   'name': 'Brandugla',
#   'soundUrl': 'https://fuglavefur.is/audio/brandugla.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/brandugla.jpg',
#   'category': 5},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Rjupa33.jpg',
#   'name': 'Rjúpa',
#   'soundUrl': 'https://fuglavefur.is/audio/rjupa.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/rjupa.jpg',
#   'category': 5},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Stelkur31.jpg',
#   'name': 'Stelkur',
#   'soundUrl': 'https://fuglavefur.is/audio/stelkur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/stelkur.jpg',
#   'category': 1},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Florgodi24.jpg',
#   'name': 'Flórgoði',
#   'soundUrl': 'https://fuglavefur.is/audio/florgodi.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/florgodi.jpg',
#   'category': 1},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Gargond08.jpg',
#   'name': 'Gargönd',
#   'soundUrl': 'https://fuglavefur.is/audio/gargond.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/gargond.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Raudhofdi11.jpg',
#   'name': 'Rauðhöfðaönd',
#   'soundUrl': 'https://fuglavefur.is/audio/raudhofdaond.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/raudhofdi.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Helsingi24.jpg',
#   'name': 'Helsingi',
#   'soundUrl': 'https://fuglavefur.is/audio/helsingi.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/helsingi.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Toppskarfur18.jpg',
#   'name': 'Toppskarfur',
#   'soundUrl': 'https://fuglavefur.is/audio/toppskarfur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/toppskarfur.jpg',
#   'category': 2},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Hrafnsond09.jpg',
#   'name': 'Hrafnsönd',
#   'soundUrl': 'https://fuglavefur.is/audio/hrafnsond.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/hrafnsond.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Straumond31.jpg',
#   'name': 'Straumönd',
#   'soundUrl': 'https://fuglavefur.is/audio/straumond.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/straumond.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Svartthrostur22.jpg',
#   'name': 'Svartþröstur',
#   'soundUrl': 'https://fuglavefur.is/audio/svartthrostur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/svartthrostur.jpg',
#   'category': 1},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Urtond39.jpg',
#   'name': 'Urtönd',
#   'soundUrl': 'https://fuglavefur.is/audio/urtond.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/urtond.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Skeidond16.jpg',
#   'name': 'Skeiðönd',
#   'soundUrl': 'https://fuglavefur.is/audio/skeidond.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/skeidond.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Hvitmafur07p.jpg',
#   'name': 'Hvítmáfur',
#   'soundUrl': 'https://fuglavefur.is/audio/hvitmafur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/hvitmafur.jpg',
#   'category': 0},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Thorshani18.jpg',
#   'name': 'Þórshani',
#   'soundUrl': 'https://fuglavefur.is/audio/thorshani.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/thorshani.jpg',
#   'category': 4},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Bjartmafur05.jpg',
#   'name': 'Bjartmáfur',
#   'soundUrl': 'https://fuglavefur.is/audio/bjartmafur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/bjartmafur.jpg',
#   'category': 0},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Grafond15.jpg',
#   'name': 'Grafönd',
#   'soundUrl': 'https://fuglavefur.is/audio/grafond.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/grafond.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Bjargdufa12.jpg',
#   'name': 'Bjargdúfa',
#   'soundUrl': 'https://fuglavefur.is/audio/bjargdufa.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/bjargdufa.jpg',
#   'category': 5},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Blesgaes37.jpg',
#   'name': 'Blesgæs',
#   'soundUrl': 'https://fuglavefur.is/audio/blesgaes.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/blesgaes.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Brandond13e.jpg',
#   'name': 'Brandönd',
#   'soundUrl': 'https://fuglavefur.is/audio/brandond.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/brandond.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Gulond19.jpg',
#   'name': 'Gulönd',
#   'soundUrl': 'https://fuglavefur.is/audio/gulond.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/gulond.jpg',
#   'category': 3},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Graspor05.jpg',
#   'name': 'Gráspör',
#   'soundUrl': 'https://fuglavefur.is/audio/graspor.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/graspor.jpg',
#   'category': 1},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Sjosvala07.jpg',
#   'name': 'Sjósvala',
#   'soundUrl': 'https://fuglavefur.is/audio/sjosvala.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/sjosvala.jpg',
#   'category': 2},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Grathrostur13.jpg',
#   'name': 'Gráþröstur',
#   'soundUrl': 'https://fuglavefur.is/audio/grathrostur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/grathrostur.jpg',
#   'category': 1},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Skrofa12.jpg',
#   'name': 'Skrofa',
#   'soundUrl': 'https://fuglavefur.is/audio/skrofa.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/skrofa.jpg',
#   'category': 2},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Stormmafur11.jpg',
#   'name': 'Stormmáfur',
#   'soundUrl': 'https://fuglavefur.is/audio/stormmafur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/stormmafur.jpg',
#   'category': 0},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Stormsvala07.jpg',
#   'name': 'Stormsvala',
#   'soundUrl': 'https://fuglavefur.is/audio/stormsvala.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/stormsvala.jpg',
#   'category': 2},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Tildra21.jpg',
#   'name': 'Tildra',
#   'soundUrl': 'https://fuglavefur.is/audio/tildra.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/tildra.jpg',
#   'category': 4},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Haftyrdill07.jpg',
#   'name': 'Haftyrðill',
#   'soundUrl': 'https://fuglavefur.is/audio/haftyrdill.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/haftyrdill.jpg',
#   'category': 2},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Glokollur19.jpg',
#   'name': 'Glókollur',
#   'soundUrl': 'https://fuglavefur.is/audio/glokollur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/glokollur.jpg',
#   'category': 1},
#  {'imgUrl': 'https://fuglavefur.is/fuglamyndir/lg/Krossnefur14.jpg',
#   'name': 'Krossnefur',
#   'soundUrl': 'https://fuglavefur.is/audio/krossnefur.ogg',
#   'thumb': 'https://fuglavefur.is/thumbs/krossnefur.jpg',
#   'category': 1}]

# %%
with open(fn, "w", encoding="utf-8") as f:
    json.dump(data,f, ensure_ascii=False)
